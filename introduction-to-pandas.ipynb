# %% [markdown]
# ## Introduction to Pandas
#
# Pandas is one of the most popular choices to load, visualize, clean, and apply statistical techniques to data. It is specially useful in Jupyter Notebooks as it lends itself to iterative exploration with cells.

# %% [markdown]
# ### Installation
#
# As always, use a virtual environment (or similar) to install pandas and its dependencies:
#
# ```dotnetcli
# $ python3 -m venv venv
# $ source venv/bin/activate
# ```
#
# The example above should work for Linux and OSX, but there is support for Windows systems as well. [Follow the documentation if you need help](https://docs.python.org/3/library/venv.html).
#
# The package to install is `pandas`

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/rohanmatre/anaconda3/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/rohanmatre/anaconda3/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/rohanmatre/anaconda3/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/rohanmatre/anaconda3/lib/python3.10/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/rohanmatre/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# ### Common operations in Pandas
#
# After installing, you will almost always see Pandas imported with an alias. This an other common practices in pandas are covered in this section.

# %%
import pandas as pd

#list of lists
data = [[4, 2, 1],
        [3, 0, 1],
        [1, 0, 0]]


columns = ['apples', 'bananas', 'oranges']
index = ['Monday', 'Tuesday', 'Wednesday']

df = pd.DataFrame(data, index, columns)
print(df)
# Out:
#            apples  bananas  oranges
# Monday          4        2        1
# Tuesday         3        0        1
# Wednesday       1        0        0
